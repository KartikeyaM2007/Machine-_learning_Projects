# %% [markdown]
# <a href="https://colab.research.google.com/github/KartikeyaM2007/Machine-_learning_Projects/blob/main/Untitled36.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fin-sentiment

# %%
# !pip install feedparser

# %%
from fin_sentiment.news_fetcher import fetch_company_news
from fin_sentiment.analyzer import SentimentAnalyzer

# %%
news = fetch_company_news("zomato", limit=10)
analyzer = SentimentAnalyzer()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2410208953.py in <cell line: 0>()
#       1 news = fetch_company_news("zomato", limit=10)
# ----> 2 analyzer = SentimentAnalyzer()
#
# /usr/local/lib/python3.12/dist-packages/fin_sentiment/analyzer.py in __init__(self)
#       5     def __init__(self):
#       6         # Load your trained LSTM model
# ----> 7         self.model = SentimentModel()
#       8
#       9     def analyze(self, text: str):
#
# /usr/local/lib/python3.12/dist-packages/fin_sentiment/sentiment_model.py in __init__(self, model_path)
#      37         # Safety check
#      38         if not os.path.exists(model_path):
# ---> 39             raise FileNotFoundError(f"❌ Model file not found at: {model_path}")
#      40
#      41         # Load checkpoint
#
# ...

# %%
for n in news:
    print(n["title"], "→", analyzer.analyze(n["title"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3558894554.py in <cell line: 0>()
#       1 for n in news:
# ----> 2     print(n["title"], "→", analyzer.analyze(n["title"]))
#
# NameError: name 'analyzer' is not defined
